# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df_vacation = pd.read_csv('../output_data/weather_output.csv')
df_vacation
# Out:
#      Unnamed: 0          City      Lat       Lng  Max Temp  Humidity  \
# 0             0    Mossamedes -15.1961   12.1522     63.18        89
# 1             1     Carnarvon -24.8667  113.6333     50.07        87
# 2             2     Compiègne  49.4179    2.8261     70.09        82
# 3             3    Butaritari   3.0707  172.7902     82.36        77
# 4             4  Punta Arenas -53.1500  -70.9167     48.22        71
# ..          ...           ...      ...       ...       ...       ...
# 567         570    Pekalongan  -6.8886  109.6753     77.95        82
# 568         571      Yashkul'  46.1711   45.3435     65.17        57
# 569         572        Baykit  61.6700   96.3700     39.85        94
# 570         573           Chu  43.5983   73.7614     61.57        32
# 571         574    Hervey Bay -25.2986  152.8535     71.04        39
#
#      Cloudiness  Wind Speed Country        Date
# 0            67        7.31      AO  1631573452
# 1             0        9.22      AU  1631573182
# 2            96        5.64      FR  1631573456
# 3            47       16.64      KI  1631573169
# 4            75       23.02      CL  1631573067
# ..          ...         ...     ...         ...
# 567          96        2.51      ID  1631574795
# 568          58        5.37      RU  1631574891
# 569          99        6.29      RU  1631574893
# 570          78        4.12      KZ  1631574896
# 571           0       13.24      AU  1631574808
#
# [572 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Access maps with unique API key
gmaps.configure(api_key=g_key)

# %%
# Store latitude and longitude in locations
locations = df_vacation[["Lat", "Lng"]]
weight = rating = df_vacation["Humidity"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=weight, 
                                 dissipating=False)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
df_vacation.dtypes
# Out:
# Unnamed: 0      int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %%
#conditions applied to select hotels
hotel_df = df_vacation.loc[(df_vacation["Max Temp"] >70) & (df_vacation["Max Temp"] <80)
                   & (df_vacation["Wind Speed"] <10)
                   & (df_vacation["Cloudiness"] ==0), : ]

hotel_df
# Out:
#      Unnamed: 0                   City      Lat       Lng  Max Temp  Humidity  \
# 39           39               Karratha -20.7377  116.8463     70.74        67
# 80           80                  Erzin  36.9559   36.2000     76.01        75
# 304         306             Cuauhtémoc  28.4167 -106.8667     75.42        26
# 307         309              Caravelas -17.7125  -39.2481     74.10        83
# 364         366  Los Llanos de Aridane  28.6585  -17.9182     73.15        89
# 371         373                 Rhodes  36.4408   28.2225     75.78        66
# 399         401                  Mahon  39.8885    4.2658     75.76        83
#
#      Cloudiness  Wind Speed Country        Date
# 39            0        5.35      AU  1631573529
# 80            0        2.06      TR  1631573619
# 304           0        5.17      MX  1631574134
# 307           0        9.08      BR  1631574142
# 364           0        1.14      ES  1631574269
# 371           0        4.00      GR  1631574235
# 399           0        8.05      ES  1631574352

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#sample of json file, read to find the structure
params = {
    
    "location": '-23.1203,-134.9692',
    "radius": 500000,
    "types": "hotel",
    "key": g_key
}
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
name_address = requests.get(base_url, params=params).json()

from pprint import pprint
pprint(name_address)
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': -23.1223034,
#                                         'lng': -134.9691543},
#                            'viewport': {'northeast': {'lat': -23.11144019441129,
#                                                       'lng': -134.9662385445423},
#                                         'southwest': {'lat': -23.12628907527434,
#                                                       'lng': -134.9718588853596}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Rikitea',
#               'photos': [{'height': 960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110710235806639825626">Hassaine '
#                                                 'Yasser</a>'],
#                           'photo_reference': 'Aap_uECoToqfyzcWUMv6rNJOX7ybTnCj3NTZDSeqx1uIWz2rpRRJ4rBLGfvXDa3um0GnixcVBAenNfym2XgMApFa_3g2gjQ2KqXS44ebtKTr3sbuBqY_sz6uL0nbE0LD4dI2cKcYTjVCp0UsvjfpQMfjtiziqUlZpKlVqSo6NiNI7ZwPlRWo',
#                           'width': 1280}],
#               'place_id': 'ChIJHzRpokmIJ54R5Qas3r5SA9I',
#               'reference': 'ChIJHzRpokmIJ54R5Qas3r5SA9I',
#               'scope': 'GOOGLE',
#               'types': ['neighborhood', 'political']},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1206197,
#                                         'lng': -134.9687529},
#                            'viewport': {'northeast': {'lat': -23.1194598197085,
#                                                       'lng': -134.9673886697085},
#                                         'southwest': {'lat': -23.1221577802915,
#                                                       'lng': -134.9700866302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'People ThankYou',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2304,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111098332724302207930">luigia '
#                                                 'b.</a>'],
#                           'photo_reference': 'Aap_uEAVBq2q_gdO850knwBTogFguK2UK0VHiA-7l_XQiy9Xdju17RymlrfunjLAqbIyRIPCMRHU-TzlEkMebUwG_if5FZZZMhoAqLYzNiHYyPxMrvfV_i7jO5eY_SMV29_f10XYE4n4ZRgXxqj23pb62FsfQg239OxWgWGElIdDV7IynqcL',
#                           'width': 4096}],
#               'place_id': 'ChIJnW6Jh0aIJ54RV2HnC1r0Hjw',
#               'plus_code': {'global_code': '5487V2HJ+QF'},
#               'rating': 4.1,
#               'reference': 'ChIJnW6Jh0aIJ54RV2HnC1r0Hjw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 18,
#               'vicinity': 'Rikitea'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1234788,
#                                         'lng': -134.9683499},
#                            'viewport': {'northeast': {'lat': -23.12216511970849,
#                                                       'lng': -134.9668725197085},
#                                         'southwest': {'lat': -23.1248630802915,
#                                                       'lng': -134.9695704802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#               'name': 'Cathedral of St. Michael Rikitea',
#               'photos': [{'height': 1728,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110710235806639825626">Hassaine '
#                                                 'Yasser</a>'],
#                           'photo_reference': 'Aap_uEA_vL-zGbn8NmQVmxGR3O0qQd3FTTafoLiqnh2JoiImYz1UbTvER7hjgqX6AMFDmCFPbtqQU-pRPIu58uRLhywnyYebB4UqZcJX7nmFhVl5BAw743TbL5FA59cD34uGB36RPq4JRo3VTCwO9eXMbandZtmm_h2I-ydr8jPnUgmM_B2K',
#                           'width': 1280}],
#               'place_id': 'ChIJPd9gClqIJ54Rzb2BD8WhkXw',
#               'rating': 3.8,
#               'reference': 'ChIJPd9gClqIJ54Rzb2BD8WhkXw',
#               'scope': 'GOOGLE',
#               'types': ['tourist_attraction',
#                         'church',
#                         'place_of_worship',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 43,
#               'vicinity': 'V2GJ+JM2'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1157428,
#                                         'lng': -134.9697357},
#                            'viewport': {'northeast': {'lat': -23.1144025697085,
#                                                       'lng': -134.9683538197085},
#                                         'southwest': {'lat': -23.11710053029151,
#                                                       'lng': -134.9710517802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#               'name': 'Magasin Keali',
#               'photos': [{'height': 2268,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103905011459061641640">Marten '
#                                                 'Horn</a>'],
#                           'photo_reference': 'Aap_uEBJxvdEYcsIZqG6teKMlpdPUsGXGmMNQd1-6B5ItZtjpM4C6ye5GIqYyIMzM-ga7Hsx8ccjK0tmQ4E-JI7FwU012-buwa6tIlUHb7tVd_D6cAsnOlYM7gIiXLPkZjjchvFMbFJvmrXuR3buhThV3hmFHSKebAQjkLSt39JELKi03BrS',
#                           'width': 4032}],
#               'place_id': 'ChIJ800ewOOJJ54RDhmWOYTI0AU',
#               'plus_code': {'global_code': '5487V2MJ+P4'},
#               'rating': 3.1,
#               'reference': 'ChIJ800ewOOJJ54RDhmWOYTI0AU',
#               'scope': 'GOOGLE',
#               'types': ['supermarket',
#                         'grocery_or_supermarket',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': 'Rikitea, Unnamed Road'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1144022,
#                                         'lng': -134.9690369},
#                            'viewport': {'northeast': {'lat': -23.1130129697085,
#                                                       'lng': -134.9677899697085},
#                                         'southwest': {'lat': -23.1157109302915,
#                                                       'lng': -134.9704879302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#               'name': 'Magasin Jojo',
#               'photos': [{'height': 2268,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103905011459061641640">Marten '
#                                                 'Horn</a>'],
#                           'photo_reference': 'Aap_uEBGcirOa89EOnxf3IMv61WluCQgnv1NppT67f61CPmrETLHt8Xtho76tJlLpMkKtO3duL41Z09IywnibPSrL_3WrKEV5Fcqp4WbXJ1veRNkT-YEUiTKNoiLmZFWuHeIenUdEFnOHoXZwjz4vkMY7UemLzy75NFu4ElTPsUiOs5i0Oui',
#                           'width': 4032}],
#               'place_id': 'ChIJ-T_rpFqJJ54RVIbUywLV5YU',
#               'plus_code': {'global_code': '5487V2PJ+69'},
#               'rating': 4.3,
#               'reference': 'ChIJ-T_rpFqJJ54RVIbUywLV5YU',
#               'scope': 'GOOGLE',
#               'types': ['supermarket',
#                         'grocery_or_supermarket',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 15,
#               'vicinity': 'Rikitea, Unnamed Road'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1255556, 'lng': -134.975},
#                            'viewport': {'northeast': {'lat': -23.12118580000001,
#                                                       'lng': -134.9739724197085},
#                                         'southwest': {'lat': -23.1270122,
#                                                       'lng': -134.9766703802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#               'icon_background_color': '#13B5C7',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/museum_pinlet',
#               'name': 'Couvent de Rouru',
#               'place_id': 'ChIJcbeMUP-JJ54Rk2QMWbzS5RM',
#               'plus_code': {'global_code': '5487V2FG+Q2'},
#               'reference': 'ChIJcbeMUP-JJ54Rk2QMWbzS5RM',
#               'scope': 'GOOGLE',
#               'types': ['museum', 'point_of_interest', 'establishment'],
#               'vicinity': 'au pied du mont Duff'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1276524,
#                                         'lng': -134.9656596},
#                            'viewport': {'northeast': {'lat': -23.1263721197085,
#                                                       'lng': -134.9643507197085},
#                                         'southwest': {'lat': -23.1290700802915,
#                                                       'lng': -134.9670486802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Pension Bianca & Benoit',
#               'photos': [{'height': 2048,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115150439809622095143">Frédérick '
#                                                 'B.</a>'],
#                           'photo_reference': 'Aap_uEAtP3W3S_H8PnjZoFmB-Fb2pMhvdZ1vddRmaNZLIfxISEXcyUnPB0ZJR04HJwzWt6fd9KwCqJMbMsrGehXMadcgNdhv_DeldDg2VKhx696UWcZSORRViL_5vHsWrGQnPWDjCnZiTKnUJdPyNkxWI9XNxL5g_4HkSes1LiscoZLGdbFo',
#                           'width': 1536}],
#               'place_id': 'ChIJib4T7laIJ54RcJ1rUHQ9KXk',
#               'plus_code': {'global_code': '5487V2CM+WP'},
#               'rating': 4.5,
#               'reference': 'ChIJib4T7laIJ54RcJ1rUHQ9KXk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 14,
#               'vicinity': 'BP 19 | Archipel des Gambier, Mangareva'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1265385,
#                                         'lng': -134.9633665},
#                            'viewport': {'northeast': {'lat': -23.1249821697085,
#                                                       'lng': -134.9625638697085},
#                                         'southwest': {'lat': -23.1276801302915,
#                                                       'lng': -134.9652618302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/camping-71.png',
#               'icon_background_color': '#4DB546',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/camping_pinlet',
#               'name': 'TEKOUTU RED BEACH I DREAM',
#               'photos': [{'height': 640,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109400836063665611136">Dani '
#                                                 'Burgundyson</a>'],
#                           'photo_reference': 'Aap_uEAPWVIibtcMGRsJ5qfr2kjCCDb0LuqhXz2kQMskN4y3yYM0DDwQRjXGF8uMOLPCD2lmcp1PiGIdAvdOTj7avUw0C7GbCJE81V5MqQbVmK8GJ5SxQRl3PXgFdyXsArQSBQlnJlm2wMNWTngLVoZMNY5fz1Tpi3GqyApZ0WOqsvLu_GQe',
#                           'width': 1280}],
#               'place_id': 'ChIJ5xY8wxKJJ54R0s3iXHTHv3Y',
#               'plus_code': {'global_code': '5487V2FP+9M'},
#               'reference': 'ChIJ5xY8wxKJJ54R0s3iXHTHv3Y',
#               'scope': 'GOOGLE',
#               'types': ['campground',
#                         'lodging',
#                         'park',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'French Polynesia'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1298303,
#                                         'lng': -134.9651985},
#                            'viewport': {'northeast': {'lat': -23.1284522697085,
#                                                       'lng': -134.9639530697085},
#                                         'southwest': {'lat': -23.1311502302915,
#                                                       'lng': -134.9666510302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Météo France, Station de Rikitea',
#               'photos': [{'height': 1707,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101672831291437754297">Matteo '
#                                                 'Saragoni</a>'],
#                           'photo_reference': 'Aap_uEC4Atr_9Fp3qhg_xP824hEx7f55CpKuXA_5Hqhhl0fBTUZ-xufeNDMilmk3pbUxhC-N2LgEiBmtYbc_pCxO-rwFcu4UJU7fWpj8-RKi-OjC3b9IavQCHPzMQKAwm405Noa6cHG-s1nmHraNBF3EOaT-WY-c_MWu3eohA2CiLlRJEaSe',
#                           'width': 2560}],
#               'place_id': 'ChIJG9et3BGJJ54RweyE6OK3LGw',
#               'plus_code': {'global_code': '5487V2CM+3W'},
#               'reference': 'ChIJG9et3BGJJ54RweyE6OK3LGw',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'vicinity': 'Unnamed Road, Gambier'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1310718,
#                                         'lng': -134.9689217},
#                            'viewport': {'northeast': {'lat': -23.12993121970849,
#                                                       'lng': -134.9673921697085},
#                                         'southwest': {'lat': -23.1326291802915,
#                                                       'lng': -134.9700901302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#13B5C7',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Couvent de Rouru',
#               'photos': [{'height': 1707,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101672831291437754297">Matteo '
#                                                 'Saragoni</a>'],
#                           'photo_reference': 'Aap_uEA_CcEcmybceqYyI-_dCS30-3t2HFqpjKZrgAYGDSPJWN9QGfF8bKxI5M0mV08etnV-95LlCnOuTKAgB9rfcfRlpavJWoPkeZ1kJ87v6S7xr9IJh9BTfqL_ZzPWMODvIKG4uLbXnwqTCCxhYv5crGoziwfDKxF_IrHPY7vpv0RFIGGr',
#                           'width': 2560}],
#               'place_id': 'ChIJtxgr95uJJ54Reu88QgMus-4',
#               'rating': 4.8,
#               'reference': 'ChIJtxgr95uJJ54Reu88QgMus-4',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 5,
#               'vicinity': 'V29J+HCG, Gambier'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.10872579999999,
#                                         'lng': -134.9752912},
#                            'viewport': {'northeast': {'lat': -23.10753996970849,
#                                                       'lng': -134.97440245},
#                                         'southwest': {'lat': -23.1102379302915,
#                                                       'lng': -134.97795745}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': 'Gendarmerie Nationale',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 494,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116506632260367591077">Gendarmerie '
#                                                 'Nationale</a>'],
#                           'photo_reference': 'Aap_uEC_wJtge_OUwwuBkENFqF7dJfVFTA52_39A3rGvOMAaRgIp95Udnd1hbOsIFCVAFuKESyIK1P3kI91vhR8d-WVYqyq5kTzTMBVUPSAZzjIIduwMRFc8nWJEtOB522XyF58_Btnh_HS69liAAMGNrcX_8XLRzkis6YMdc0eeV2fRuIpT',
#                           'width': 878}],
#               'place_id': 'ChIJe6TjLUGJJ54RmYDOcAgfYso',
#               'plus_code': {'global_code': '5487V2RF+GV'},
#               'reference': 'ChIJe6TjLUGJJ54RmYDOcAgfYso',
#               'scope': 'GOOGLE',
#               'types': ['police',
#                         'local_government_office',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'French Polynesia'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1127486,
#                                         'lng': -134.9849372},
#                            'viewport': {'northeast': {'lat': -23.1113996197085,
#                                                       'lng': -134.9835882197085},
#                                         'southwest': {'lat': -23.1140975802915,
#                                                       'lng': -134.9862861802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': 'Baie de Ngatavake',
#               'place_id': 'ChIJCY8MR1GJJ54Ref3Jk6O0Rxs',
#               'plus_code': {'global_code': '5487V2P8+W2'},
#               'reference': 'ChIJCY8MR1GJJ54Ref3Jk6O0Rxs',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'vicinity': 'Unnamed Road, Gambier'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.0902538,
#                                         'lng': -134.9372232},
#                            'viewport': {'northeast': {'lat': -23.08891656970849,
#                                                       'lng': -134.9358720197085},
#                                         'southwest': {'lat': -23.0916145302915,
#                                                       'lng': -134.9385699802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Pension Chez Jojo',
#               'place_id': 'ChIJZ7Va7siHJ54Rxz2-_UBfZaY',
#               'plus_code': {'global_code': '5487W357+V4'},
#               'reference': 'ChIJZ7Va7siHJ54Rxz2-_UBfZaY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Unnamed Road, Gambier'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1451982,
#                                         'lng': -135.0294839},
#                            'viewport': {'northeast': {'lat': -23.1438492197085,
#                                                       'lng': -135.0281349197085},
#                                         'southwest': {'lat': -23.1465471802915,
#                                                       'lng': -135.0308328802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#               'name': 'Saint-Gabriel',
#               'photos': [{'height': 1707,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101672831291437754297">Matteo '
#                                                 'Saragoni</a>'],
#                           'photo_reference': 'Aap_uECNu1T4cSoxgkT4t_tMYaGzttxaf5J_kS9ePAMlr0JAhZEsN9Fzym0V7tjhBTGCJ3SwPFcD4mlGhp0WAaIvZee5LfvO3N-rC8R5HDtmDo3YVaDQ_WRRgbKaxi5jXgqNxm31l-BtZ8LHOy33HdyTcmVpK7UcaC6yGmrcT9rjvcomNJ7i',
#                           'width': 2560}],
#               'place_id': 'ChIJM9--IwIniHUR5pg-g7ouRh4',
#               'rating': 5,
#               'reference': 'ChIJM9--IwIniHUR5pg-g7ouRh4',
#               'scope': 'GOOGLE',
#               'types': ['church',
#                         'place_of_worship',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': 'VX3C+W6C, Gambier'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -23.1811638,
#                                         'lng': -134.9134351},
#                            'viewport': {'northeast': {'lat': -23.1798196197085,
#                                                       'lng': -134.9122853197085},
#                                         'southwest': {'lat': -23.1825175802915,
#                                                       'lng': -134.9149832802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#               'name': 'Notre-Dame de la Paix',
#               'photos': [{'height': 1707,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101672831291437754297">Matteo '
#                                                 'Saragoni</a>'],
#                           'photo_reference': 'Aap_uEDNSiJ_UJ1c_g_xXcA_Ag4ruAXxj6sPW08oK1Wghba36c1o5raOQCJJ9jC5uVbWTY38cZdYj-pz6PvrmZHAxW76Q2kq2SFpPrAY1_8NX-g4lYRFNawAmSHKvPrQrC-Frd7VBJWixtkDmaOj5lWHhc2h3yX20OX4kyaTP4sByKfX4A1J',
#                           'width': 2560}],
#               'place_id': 'ChIJ9_RoNluPJ54Rb2DJTBM5yxM',
#               'plus_code': {'global_code': '5487R39P+GJ'},
#               'rating': 5,
#               'reference': 'ChIJ9_RoNluPJ54Rb2DJTBM5yxM',
#               'scope': 'GOOGLE',
#               'types': ['church',
#                         'place_of_worship',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 4,
#               'vicinity': 'Akamaru, Gambier'},
#              {'geometry': {'location': {'lat': -23.0790577, 'lng': -134.891171},
#                            'viewport': {'northeast': {'lat': -23.07200926788035,
#                                                       'lng': -134.8817324717545},
#                                         'southwest': {'lat': -23.08825054331614,
#                                                       'lng': -134.8983259414333}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png',
#               'icon_background_color': '#10BDFF',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/airport_pinlet',
#               'name': 'Totegegie Airport',
#               'place_id': 'ChIJoWGt8FaEJ54R6CgXGF85ljo',
#               'reference': 'ChIJoWGt8FaEJ54R6CgXGF85ljo',
#               'scope': 'GOOGLE',
#               'types': ['airport',
#                         'premise',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'Gambier'},
#              {'geometry': {'location': {'lat': -23.14523, 'lng': -135.029443},
#                            'viewport': {'northeast': {'lat': -23.14229130227338,
#                                                       'lng': -135.0281363264571},
#                                         'southwest': {'lat': -23.1487076125489,
#                                                       'lng': -135.0308342870401}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Taravai',
#               'place_id': 'ChIJxVF-ph0niHURd44HrcoNesE',
#               'reference': 'ChIJxVF-ph0niHURd44HrcoNesE',
#               'scope': 'GOOGLE',
#               'types': ['neighborhood', 'political'],
#               'vicinity': 'Gambier'}],
#  'status': 'OK'}

# %%
# params dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "lodging",
    "key": g_key
}

# Use the lat/lng we recovered to identify hotels
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    

    # convert to json
    name_address = name_address.json()
    

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index,"Hotel Name"] = name_address["results"][0]["name"]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# /Users/ziliangzhang/opt/anaconda3/envs/bootcamp/lib/python3.8/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/ziliangzhang/opt/anaconda3/envs/bootcamp/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
hotel_df
# Out:
#      Unnamed: 0                   City      Lat       Lng  Max Temp  Humidity  \
# 39           39               Karratha -20.7377  116.8463     70.74        67
# 80           80                  Erzin  36.9559   36.2000     76.01        75
# 304         306             Cuauhtémoc  28.4167 -106.8667     75.42        26
# 307         309              Caravelas -17.7125  -39.2481     74.10        83
# 364         366  Los Llanos de Aridane  28.6585  -17.9182     73.15        89
# 371         373                 Rhodes  36.4408   28.2225     75.78        66
# 399         401                  Mahon  39.8885    4.2658     75.76        83
#
#      Cloudiness  Wind Speed Country        Date  \
# 39            0        5.35      AU  1631573529
# 80            0        2.06      TR  1631573619
# 304           0        5.17      MX  1631574134
# 307           0        9.08      BR  1631574142
# 364           0        1.14      ES  1631574269
# 371           0        4.00      GR  1631574235
# 399           0        8.05      ES  1631574352
#
#                                Hotel Name
# 39                   ibis Styles Karratha
# 80                   Büyük Osmaniye Oteli
# 304                  Motel Tarahumara Inn
# 307                  Pousada Verdes Mares
# 364                  H10 Taburiente Playa
# 371  Spirit of the Knights Boutique Hotel
# 399                          ARTIEM Capri

# %% [markdown]
# # NOTE: Do not change any of the code in this cell
#
# # Using the template add the hotel marks to the heatmap
# info_box_template = """
# <dl>
# <dt>Name</dt><dd>{Hotel Name}</dd>
# <dt>City</dt><dd>{City}</dd>
# <dt>Country</dt><dd>{Country}</dd>
# </dl>
# """
# # Store the DataFrame Row
# # NOTE: be sure to update with your DataFrame name
# hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
# locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

# Assign the marker layer to a variable
locations = hotel_df[["Lat", "Lng"]]
markers = gmaps.marker_layer(locations)

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""

# Store the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# Create hotel symbol layer
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=hotel_info
)
# Add the layer to the map
fig.add_layer(markers)
fig.add_layer(hotel_layer)
fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
